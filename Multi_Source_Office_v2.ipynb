# %%
# @title Load a drive in in the notebook
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# @title Import necessary libraries and dependencies
import tensorflow
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Activation, Dropout, Flatten, Conv2D, MaxPooling2D, Input, concatenate
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import Model
from sklearn.model_selection import RepeatedKFold
from os import listdir
from os.path import isfile, join
import sys
import cv2
import math
import os
import numpy as np
MainFolder ='/content/drive/MyDrive/Office/domain_adaptation_images/'

# %%
# Load the dataset
dataset = 'dslr' #@param ["amazon", "webcam", "dslr"]
dataset_folder=MainFolder+dataset+'/images/'
x=[]
y=[]
classes=['back_pack','desk_lamp','mobile_phone','printer','stapler','bike','desktop_computer','monitor','projector','tape_dispenser','bike_helmet',
           'file_cabinet','mouse','punchers','trash_can','bookcase','headphones','mug','ring_binder','bottle','keyboard','paper_notebook','ruler','calculator',
           'laptop_computer','pen','scissors','desk_chair','letter_tray','phone','speaker']
c_discretized=0
for c in classes:
  data = os.listdir(dataset_folder+c)
  for image in data:
    x.append(cv2.resize(cv2.imread(dataset_folder+c+'/'+image), (224,224))/255.0)
    y.append(c_discretized)
  c_discretized+=1
x=np.array(x)
y=(np.array(y))

# %% [markdown]
# # Train From Scratch

# %%
def AlexNetModel():
  # Create AlexNet architecture
  AlexNet=Sequential()

  #1st Convolutional Layer
  AlexNet.add(Conv2D(filters=96, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='same', name='conv2d'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #2nd Convolutional Layer
  AlexNet.add(Conv2D(filters=256, kernel_size=(5, 5), strides=(1,1), padding='same', name='Conv2d_1'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #3rd Convolutional Layer
  AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_2'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))

  #4th Convolutional Layer
  AlexNet.add(Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_3'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))

  #5th Convolutional Layer
  AlexNet.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_4'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #Passing it to a Fully Connected layer
  AlexNet.add(Flatten())
  # 1st Fully Connected Layer
  AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  # Add Dropout to prevent overfitting
  AlexNet.add(Dropout(0.4))

  #2nd Fully Connected Layer
  AlexNet.add(Dense(4096))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  #Add Dropout
  AlexNet.add(Dropout(0.4))

  #3rd Fully Connected Layer
  AlexNet.add(Dense(1000))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  #Add Dropout
  AlexNet.add(Dropout(0.4))

  #Output Layer
  AlexNet.add(Dense(len(classes)))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('softmax'))

  return AlexNet

# %%
# To compare our work, the SOTA repeat 5-fold 2 times
# create k-fold with k=5
kfold = RepeatedKFold(n_splits=5, n_repeats=2)
results_acc=[]
results_val=[]
cont=1

for train, test in kfold.split(x):
  tensorflow.keras.backend.clear_session()
  print('-------------------------------------------------------------------------------------')
  print('Split:',cont)
  print('-------------------------------------------------------------------------------------')
  cont+=1
  #get the new model
  model=AlexNetModel()
  # callback to save the best models
  checkpoint_filepath = 'drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/'+dataset+'/checkpoint_'+str(cont)+'.h5'
  model_checkpoint=tensorflow.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
  # compile, fit the model and save the model
  model.compile(loss = keras.losses.categorical_crossentropy, optimizer= tensorflow.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9), metrics=['accuracy'])
  history=model.fit(x[train] , to_categorical(y[train]), validation_data=(x[test], to_categorical(y[test])), epochs = 100, callbacks=[model_checkpoint], batch_size=32)
  results_acc.append((history.history['accuracy']))
  results_val.append((history.history['val_accuracy']))
# Out:
# -------------------------------------------------------------------------------------
# Split: 1
# -------------------------------------------------------------------------------------
# Epoch 1/100
# 20/20 [==============================] - 15s 776ms/step - loss: 0.9979 - accuracy: 0.8931 - val_loss: 1.4469 - val_accuracy: 0.7358
# Epoch 21/100
# 20/20 [==============================] - 12s 643ms/step - loss: 0.9532 - accuracy: 0.9104 - val_loss: 1.2888 - val_accuracy: 0.7610
# Epoch 22/100
# 20/20 [==============================] - 12s 624ms/step - loss: 0.9410 - accuracy: 0.9009 - val_loss: 1.2958 - val_accuracy: 0.7673
# Epoch 23/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.8889 - accuracy: 0.8994 - val_loss: 1.2920 - val_accuracy: 0.7547
# Epoch 24/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.8504 - accuracy: 0.9214 - val_loss: 1.2181 - val_accuracy: 0.7673
# Epoch 25/100
# 20/20 [==============================] - 8s 390ms/step - loss: 0.8449 - accuracy: 0.9261 - val_loss: 1.1780 - val_accuracy: 0.7799
# Epoch 26/100
# 20/20 [==============================] - 15s 807ms/step - loss: 0.8373 - accuracy: 0.9151 - val_loss: 1.1254 - val_accuracy: 0.7925
# Epoch 27/100
# 20/20 [==============================] - 14s 735ms/step - loss: 0.7781 - accuracy: 0.9340 - val_loss: 1.0964 - val_accuracy: 0.8050
# Epoch 28/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.7659 - accuracy: 0.9418 - val_loss: 1.1003 - val_accuracy: 0.7925
# Epoch 29/100
# 20/20 [==============================] - 3s 131ms/step - loss: 0.7490 - accuracy: 0.9182 - val_loss: 1.0341 - val_accuracy: 0.8050
# Epoch 30/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.7203 - accuracy: 0.9387 - val_loss: 1.0297 - val_accuracy: 0.8050
# Epoch 31/100
# 20/20 [==============================] - 6s 294ms/step - loss: 0.7100 - accuracy: 0.9465 - val_loss: 1.0177 - val_accuracy: 0.8176
# Epoch 32/100
# 20/20 [==============================] - 12s 602ms/step - loss: 0.6426 - accuracy: 0.9591 - val_loss: 1.0168 - val_accuracy: 0.8239
# Epoch 33/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.7154 - accuracy: 0.9403 - val_loss: 1.0223 - val_accuracy: 0.8113
# Epoch 34/100
# 20/20 [==============================] - 3s 132ms/step - loss: 0.6908 - accuracy: 0.9324 - val_loss: 1.0271 - val_accuracy: 0.8050
# Epoch 35/100
# 20/20 [==============================] - 3s 131ms/step - loss: 0.6554 - accuracy: 0.9528 - val_loss: 1.0046 - val_accuracy: 0.7987
# Epoch 36/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.6442 - accuracy: 0.9403 - val_loss: 0.9482 - val_accuracy: 0.8176
# Epoch 37/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.6043 - accuracy: 0.9607 - val_loss: 0.9530 - val_accuracy: 0.8050
# Epoch 38/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.6091 - accuracy: 0.9403 - val_loss: 0.9376 - val_accuracy: 0.8176
# Epoch 39/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.6041 - accuracy: 0.9528 - val_loss: 0.9374 - val_accuracy: 0.8239
# Epoch 40/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.5816 - accuracy: 0.9575 - val_loss: 0.9019 - val_accuracy: 0.8113
# Epoch 41/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.5765 - accuracy: 0.9591 - val_loss: 0.9060 - val_accuracy: 0.8239
# Epoch 42/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.5469 - accuracy: 0.9591 - val_loss: 0.9203 - val_accuracy: 0.8239
# Epoch 43/100
# 20/20 [==============================] - 10s 497ms/step - loss: 0.5243 - accuracy: 0.9638 - val_loss: 0.9038 - val_accuracy: 0.8302
# Epoch 44/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.5531 - accuracy: 0.9717 - val_loss: 0.8920 - val_accuracy: 0.8302
# Epoch 45/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.5014 - accuracy: 0.9796 - val_loss: 0.8889 - val_accuracy: 0.8239
# Epoch 46/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0
100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.8402 - accuracy: 0.9277 - val_loss: 1.3363 - val_accuracy: 0.7107
# Epoch 25/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.7902 - accuracy: 0.9308 - val_loss: 1.3085 - val_accuracy: 0.6918
# Epoch 26/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.7968 - accuracy: 0.9340 - val_loss: 1.1864 - val_accuracy: 0.7799
# Epoch 27/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.7140 - accuracy: 0.9513 - val_loss: 1.1199 - val_accuracy: 0.7799
# Epoch 28/100
# 20/20 [==============================] - 14s 755ms/step - loss: 0.7737 - accuracy: 0.9371 - val_loss: 1.0986 - val_accuracy: 0.7925
# Epoch 29/100
# 20/20 [==============================] - 13s 659ms/step - loss: 0.7345 - accuracy: 0.9355 - val_loss: 1.0615 - val_accuracy: 0.7987
# Epoch 30/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.6924 - accuracy: 0.9481 - val_loss: 1.0713 - val_accuracy: 0.7987
# Epoch 31/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.7285 - accuracy: 0.9355 - val_loss: 1.0733 - val_accuracy: 0.7925
# Epoch 32/100
# 20/20 [==============================] - 6s 310ms/step - loss: 0.7128 - accuracy: 0.9340 - val_loss: 1.0439 - val_accuracy: 0.8113
# Epoch 33/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.6578 - accuracy: 0.9528 - val_loss: 1.0349 - val_accuracy: 0.8113
# Epoch 34/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.6523 - accuracy: 0.9544 - val_loss: 1.0162 - val_accuracy: 0.7987
# Epoch 35/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.6150 - accuracy: 0.9528 - val_loss: 0.9825 - val_accuracy: 0.7987
# Epoch 36/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.6241 - accuracy: 0.9544 - val_loss: 0.9096 - val_accuracy: 0.7987
# Epoch 37/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.6075 - accuracy: 0.9434 - val_loss: 0.9254 - val_accuracy: 0.7925
# Epoch 38/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.6068 - accuracy: 0.9465 - val_loss: 0.9118 - val_accuracy: 0.7925
# Epoch 39/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.5684 - accuracy: 0.9717 - val_loss: 0.9198 - val_accuracy: 0.7987
# Epoch 40/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.5881 - accuracy: 0.9560 - val_loss: 0.8969 - val_accuracy: 0.8113
# Epoch 41/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.5489 - accuracy: 0.9591 - val_loss: 0.8807 - val_accuracy: 0.7987
# Epoch 42/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.5506 - accuracy: 0.9591 - val_loss: 0.9200 - val_accuracy: 0.7799
# Epoch 43/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.5024 - accuracy: 0.9638 - val_loss: 0.8953 - val_accuracy: 0.7862
# Epoch 44/100
# 20/20 [==============================] - 10s 505ms/step - loss: 0.5060 - accuracy: 0.9670 - val_loss: 0.8601 - val_accuracy: 0.8176
# Epoch 45/100
# 20/20 [==============================] - 3s 141ms/step - loss: 0.5056 - accuracy: 0.9780 - val_loss: 0.9345 - val_accuracy: 0.7925
# Epoch 46/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.5147 - accuracy: 0.9717 - val_loss: 0.9000 - val_accuracy: 0.8050
# Epoch 47/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.5385 - accuracy: 0.9560 - val_loss: 0.8822 - val_accuracy: 0.8050
# Epoch 48/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.4715 - accuracy: 0.9701 - val_loss: 0.8742 - val_accuracy: 0.8113
# Epoch 49/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.4821 - accuracy: 0.9575 - val_loss: 0.8481 - val_accuracy: 0.8113
# Epoch 50/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.
100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3465 - accuracy: 0.9827 - val_loss: 0.7383 - val_accuracy: 0.8365
# Epoch 80/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.3232 - accuracy: 0.9874 - val_loss: 0.7420 - val_accuracy: 0.8302
# Epoch 81/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3295 - accuracy: 0.9748 - val_loss: 0.7248 - val_accuracy: 0.8365
# Epoch 82/100
# 20/20 [==============================] - 17s 869ms/step - loss: 0.3046 - accuracy: 0.9937 - val_loss: 0.7062 - val_accuracy: 0.8491
# Epoch 83/100
# 20/20 [==============================] - 3s 141ms/step - loss: 0.3474 - accuracy: 0.9827 - val_loss: 0.7349 - val_accuracy: 0.8239
# Epoch 84/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.3387 - accuracy: 0.9701 - val_loss: 0.7551 - val_accuracy: 0.8302
# Epoch 85/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.2972 - accuracy: 0.9827 - val_loss: 0.7952 - val_accuracy: 0.8113
# Epoch 86/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3752 - accuracy: 0.9701 - val_loss: 0.7351 - val_accuracy: 0.8302
# Epoch 87/100
# 20/20 [==============================] - 3s 142ms/step - loss: 0.3320 - accuracy: 0.9748 - val_loss: 0.6999 - val_accuracy: 0.8239
# Epoch 88/100
# 20/20 [==============================] - 3s 142ms/step - loss: 0.3058 - accuracy: 0.9796 - val_loss: 0.7162 - val_accuracy: 0.8113
# Epoch 89/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2863 - accuracy: 0.9906 - val_loss: 0.7361 - val_accuracy: 0.8176
# Epoch 90/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2807 - accuracy: 0.9858 - val_loss: 0.7303 - val_accuracy: 0.8302
# Epoch 91/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2884 - accuracy: 0.9874 - val_loss: 0.7018 - val_accuracy: 0.8302
# Epoch 92/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3094 - accuracy: 0.9717 - val_loss: 0.7134 - val_accuracy: 0.8239
# Epoch 93/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3131 - accuracy: 0.9811 - val_loss: 0.6923 - val_accuracy: 0.8176
# Epoch 94/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2858 - accuracy: 0.9890 - val_loss: 0.6913 - val_accuracy: 0.8239
# Epoch 95/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.3042 - accuracy: 0.9811 - val_loss: 0.7129 - val_accuracy: 0.8113
# Epoch 96/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2658 - accuracy: 0.9780 - val_loss: 0.6954 - val_accuracy: 0.8176
# Epoch 97/100
# 20/20 [==============================] - 3s 134ms/step - loss: 0.2971 - accuracy: 0.9764 - val_loss: 0.6716 - val_accuracy: 0.8302
# Epoch 98/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.2717 - accuracy: 0.9858 - val_loss: 0.6661 - val_accuracy: 0.8365
# Epoch 99/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3008 - accuracy: 0.9764 - val_loss: 0.6444 - val_accuracy: 0.8428
# Epoch 100/100
# 20/20 [==============================] - 3s 133ms/step - loss: 0.2606 - accuracy: 0.9843 - val_loss: 0.6638 - val_accuracy: 0.8365
# -------------------------------------------------------------------------------------
# Split: 4
# -------------------------------------------------------------------------------------
# Epoch 1/100
# 20/20 [==============================] - 36s 2s/step - loss: 3.6243 - accuracy: 0.0440 - val_loss: 3.5001 - val_accuracy: 0.0503
# Epoch 2/100
# 20/20 [==============================] - 6s 288ms/step - loss: 3.0005 - accuracy: 0.1619 - val_loss: 4.5031 - val_accuracy: 0.0881
# Epoch 3/100
# 20/20 [==============================] - 6s 299ms/step - loss: 2.4632 - accuracy: 0.3679 - val_loss: 4.1334 - val_accuracy: 0.0943
100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.8463 - accuracy: 0.9198 - val_loss: 1.3682 - val_accuracy: 0.6981
# Epoch 24/100
# 20/20 [==============================] - 10s 513ms/step - loss: 0.8531 - accuracy: 0.9261 - val_loss: 1.2280 - val_accuracy: 0.7484
# Epoch 25/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.8199 - accuracy: 0.9151 - val_loss: 1.2206 - val_accuracy: 0.7484
# Epoch 26/100
# 20/20 [==============================] - 11s 596ms/step - loss: 0.7736 - accuracy: 0.9308 - val_loss: 1.1276 - val_accuracy: 0.7610
# Epoch 27/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.7676 - accuracy: 0.9434 - val_loss: 1.1426 - val_accuracy: 0.7610
# Epoch 28/100
# 20/20 [==============================] - 8s 396ms/step - loss: 0.7388 - accuracy: 0.9387 - val_loss: 1.0790 - val_accuracy: 0.7799
# ...
# Epoch 92/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.2944 - accuracy: 0.9890 - val_loss: 0.7512 - val_accuracy: 0.8365
# Epoch 93/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3210 - accuracy: 0.9796 - val_loss: 0.7411 - val_accuracy: 0.8302
# Epoch 94/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3302 - accuracy: 0.9858 - val_loss: 0.7450 - val_accuracy: 0.8428
# Epoch 95/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3338 - accuracy: 0.9748 - val_loss: 0.7164 - val_accuracy: 0.8491
# Epoch 96/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.3012 - accuracy: 0.9780 - val_loss: 0.7257 - val_accuracy: 0.8491
# Epoch 97/100
# 20/20 [==============================] - 3s 144ms/step - loss: 0.3017 - accuracy: 0.9827 - val_loss: 0.7368 - val_accuracy: 0.8428
# Epoch 98/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.2904 - accuracy: 0.9796 - val_loss: 0.7372 - val_accuracy: 0.8302
# Epoch 99/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2710 - accuracy: 0.9874 - val_loss: 0.7445 - val_accuracy: 0.8302
# Epoch 100/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.2658 - accuracy: 0.9827 - val_loss: 0.7410 - val_accuracy: 0.8491
# -------------------------------------------------------------------------------------
# Split: 10
# -------------------------------------------------------------------------------------
# Epoch 1/100
# 20/20 [==============================] - 8s 325ms/step - loss: 3.7037 - accuracy: 0.0393 - val_loss: 3.4322 - val_accuracy: 0.0314
# Epoch 2/100
# 20/20 [==============================] - 3s 141ms/step - loss: 3.0157 - accuracy: 0.1431 - val_loss: 3.8922 - val_accuracy: 0.0314
# Epoch 3/100
# 20/20 [==============================] - 5s 280ms/step - loss: 2.4917 - accuracy: 0.3396 - val_loss: 3.6593 - val_accuracy: 0.0503
# Epoch 4/100
# 20/20 [==============================] - 6s 292ms/step - loss: 2.2058 - accuracy: 0.4607 - val_loss: 3.2823 - val_accuracy: 0.0755
# Epoch 5/100
# 20/20 [==============================] - 12s 615ms/step - loss: 1.9512 - accuracy: 0.5487 - val_loss: 3.1096 - val_accuracy: 0.1006
# Epoch 6/100
# 20/20 [==============================] - 12s 629ms/step - loss: 1.8760 - accuracy: 0.5692 - val_loss: 3.0084 - val_accuracy: 0.2138
# Epoch 7/100
# 20/20 [==============================] - 17s 878ms/step - loss: 1.7347 - accuracy: 0.6368 - val_loss: 2.8981 - val_accuracy: 0.2704
# Epoch 8/100
# 20/20 [==============================] - 13s 656ms/step - loss: 1.6155 - accuracy: 0.6887 - val_loss: 2.7702 - val_accuracy: 0.3145
# Epoch 9/100
# 20/20 [==============================] - 13s 670ms/step - loss: 1.5438 - accuracy: 0.7186 - val_loss: 2.6126 - val_accuracy: 0.3459
# Epoch 10/100
# 20/20 [==============================] - 16s 824ms/step - loss: 1.5038 - accuracy: 0.7013 - val_loss: 2.5145 - val_accuracy: 0.3585
# Epoch 11/100
# 20/20 [==============================] - 12s 622ms/step - loss: 1.3627 - accuracy: 0.7956 - val_loss: 2.3915 - val_accuracy: 0.4214
# Epoch 12/100
# 20/20 [==============================] - 14s 732ms/step - loss: 1.3237 - accuracy: 0.7956 - val_loss: 2.2885 - val_accuracy: 0.4277
# Epoch 13/100
# 20/20 [==============================] - 13s 673ms/step - loss: 1.3061 - accuracy: 0.7956 - val_loss: 2.0221 - val_accuracy: 0.5283
# Epoch 14/100
# 20/20 [==============================] - 12s 606ms/step - loss: 1.2645 - accuracy: 0.8035 - val_loss: 1.9210 - val_accuracy: 0.5660
# Epoch 15/100
# 20/20 [==============================] - 17s 887ms/step - loss: 1.1729 - accuracy: 0.8396 - val_loss: 1.8970 - val_accuracy: 0.5786
# Epoch 16/100
# 20/20 [==============================] - 13s 692ms/step - loss: 1.1056 - accuracy: 0.8585 - val_loss: 1.7324 - val_accuracy: 0.5975
# Epoch 17/100
# 20/20 [==============================] - 13s 683ms/step - loss: 1.0789 - accuracy: 0.8852 - val_loss: 1.5230 - val_accuracy: 0.6415
# Epoch 18/100
# 20/20 [==============================] - 13s 656ms/step - loss: 1.0287 - accuracy: 0.8994 - val_loss: 1.4579 - val_accuracy: 0.6541
# Epoch 19/100
# 20/20 [==============================] - 16s 815ms/step - loss: 0.9977 - accuracy: 0.8711 - val_loss: 1.4367 - val_accuracy: 0.6792
# Epoch 20/100
# 20/20 [==============================] - 13s 659ms/step - loss: 0.9864 - accuracy: 0.9072 - val_loss: 1.3270 - val_accuracy: 0.6981
# Epoch 21/100
# 20/20 [==============================] - 14s 711ms/step - loss: 0.9839 - accuracy: 0.8805 - val_loss: 1.3304 - val_accuracy: 0.7107
# Epoch 22/100
# 20/20 [==============================] - 14s 753ms/step - loss: 0.8886 - accuracy: 0.9135 - val_loss: 1.2207 - val_accuracy: 0.7358
# Epoch 23/100
# 20/20 [==============================] - 11s 552ms/step - loss: 0.9168 - accuracy: 0.9025 - val_loss: 1.1960 - val_accuracy: 0.7421
# Epoch 24/100
# 20/20 [==============================] - 13s 679ms/step - loss: 0.8667 - accuracy: 0.9104 - val_loss: 1.0714 - val_accuracy: 0.7673
# Epoch 25/100
# 20/20 [==============================] - 16s 847ms/step - loss: 0.8192 - accuracy: 0.9167 - val_loss: 1.0562 - val_accuracy: 0.7799
# Epoch 26/100
# 20/20 [==============================] - 14s 733ms/step - loss: 0.7864 - accuracy: 0.9387 - val_loss: 0.9906 - val_accuracy: 0.8050
# Epoch 27/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.8144 - accuracy: 0.9167 - val_loss: 1.0044 - val_accuracy: 0.8050
# Epoch 28/100
# 20/20 [==============================] - 10s 508ms/step - loss: 0.7486 - accuracy: 0.9387 - val_loss: 0.9638 - val_accuracy: 0.8239
# Epoch 29/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.7820 - accuracy: 0.9277 - val_loss: 0.9785 - val_accuracy: 0.8050
# Epoch 30/100
# 20/20 [==============================] - 10s 498ms/step - loss: 0.6741 - accuracy: 0.9465 - val_loss: 0.8826 - val_accuracy: 0.8365
# Epoch 31/100
# 20/20 [==============================] - 3s 144ms/step - loss: 0.6917 - accuracy: 0.9528 - val_loss: 0.9465 - val_accuracy: 0.8113
# Epoch 32/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.6954 - accuracy: 0.9513 - val_loss: 0.8584 - val_accuracy: 0.8365
# Epoch 33/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.6446 - accuracy: 0.9528 - val_loss: 0.8803 - val_accuracy: 0.8302
# Epoch 34/100
# 20/20 [==============================] - 3s 144ms/step - loss: 0.6586 - accuracy: 0.9481 - val_loss: 0.8761 - val_accuracy: 0.8302
# Epoch 35/100
# 20/20 [==============================] - 3s 144ms/step - loss: 0.6188 - accuracy: 0.9607 - val_loss: 0.8212 - val_accuracy: 0.8365
# Epoch 36/100
# 20/20 [==============================] - 10s 507ms/step - loss: 0.6333 - accuracy: 0.9623 - val_loss: 0.8021 - val_accuracy: 0.8428
# Epoch 37/100
# 20/20 [==============================] - 15s 793ms/step - loss: 0.6116 - accuracy: 0.9575 - val_loss: 0.7765 - val_accuracy: 0.8679
# Epoch 38/100
# 20/20 [==============================] - 12s 630ms/step - loss: 0.6250 - accuracy: 0.9403 - val_loss: 0.7650 - val_accuracy: 0.8742
# Epoch 39/100
# 20/20 [==============================] - 3s 143ms/step - loss: 0.5788 - accuracy: 0.9670 - val_loss: 0.7511 - val_accuracy: 0.8616
# Epoch 40/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.5408 - accuracy: 0.9638 - val_loss: 0.7482 - val_accuracy: 0.8491
# Epoch 41/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.5842 - accuracy: 0.9513 - val_loss: 0.7843 - val_accuracy: 0.8679
# Epoch 42/100
# 20/20 [==============================] - 3s 148ms/step - loss: 0.5307 - accuracy: 0.9733 - val_loss: 0.7276 - val_accuracy: 0.8553
# Epoch 43/100
# 20/20 [==============================] - 3s 147ms/step - loss: 0.5778 - accuracy: 0.9623 - val_loss: 0.7140 - val_accuracy: 0.8679
# Epoch 44/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.5416 - accuracy: 0.9654 - val_loss: 0.7365 - val_accuracy: 0.8491
# Epoch 45/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.5135 - accuracy: 0.9733 - val_loss: 0.7191 - val_accuracy: 0.8553
# Epoch 46/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.5057 - accuracy: 0.9701 - val_loss: 0.6942 - val_accuracy: 0.8491
# Epoch 47/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.4932 - accuracy: 0.9670 - val_loss: 0.6867 - val_accuracy: 0.8616
# Epoch 48/100
# 20/20 [==============================] - 3s 141ms/step - loss: 0.4728 - accuracy: 0.9811 - val_loss: 0.6631 - val_accuracy: 0.8679
# Epoch 49/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.4970 - accuracy: 0.9560 - val_loss: 0.6650 - val_accuracy: 0.8616
# Epoch 50/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.4747 - accuracy: 0.9701 - val_loss: 0.6654 - val_accuracy: 0.8616
# Epoch 51/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.5059 - accuracy: 0.9701 - val_loss: 0.6657 - val_accuracy: 0.8742
# Epoch 52/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.4923 - accuracy: 0.9591 - val_loss: 0.6698 - val_accuracy: 0.8742
# Epoch 53/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.4697 - accuracy: 0.9811 - val_loss: 0.6531 - val_accuracy: 0.8553
# Epoch 54/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.4488 - accuracy: 0.9748 - val_loss: 0.6680 - val_accuracy: 0.8491
# Epoch 55/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.4374 - accuracy: 0.9686 - val_loss: 0.6450 - val_accuracy: 0.8742
# Epoch 56/100
# 20/20 [==============================] - 10s 510ms/step - loss: 0.4484 - accuracy: 0.9733 - val_loss: 0.6496 - val_accuracy: 0.8931
# Epoch 57/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.4538 - accuracy: 0.9717 - val_loss: 0.6685 - val_accuracy: 0.8679
# Epoch 58/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.4322 - accuracy: 0.9780 - val_loss: 0.6307 - val_accuracy: 0.8491
# Epoch 59/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.4391 - accuracy: 0.9701 - val_loss: 0.6470 - val_accuracy: 0.8428
# Epoch 60/100
# 20/20 [==============================] - 3s 151ms/step - loss: 0.3918 - accuracy: 0.9780 - val_loss: 0.6427 - val_accuracy: 0.8742
# Epoch 61/100
# 20/20 [==============================] - 3s 143ms/step - loss: 0.4246 - accuracy: 0.9733 - val_loss: 0.6259 - val_accuracy: 0.8742
# Epoch 62/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.4099 - accuracy: 0.9796 - val_loss: 0.5964 - val_accuracy: 0.8868
# Epoch 63/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3950 - accuracy: 0.9717 - val_loss: 0.5889 - val_accuracy: 0.8868
# Epoch 64/100
# 20/20 [==============================] - 10s 499ms/step - loss: 0.3797 - accuracy: 0.9717 - val_loss: 0.6228 - val_accuracy: 0.8994
# Epoch 65/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3889 - accuracy: 0.9764 - val_loss: 0.6153 - val_accuracy: 0.8994
# Epoch 66/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.3542 - accuracy: 0.9858 - val_loss: 0.5733 - val_accuracy: 0.8931
# Epoch 67/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.3781 - accuracy: 0.9717 - val_loss: 0.5807 - val_accuracy: 0.8679
# Epoch 68/100
# 20/20 [==============================] - 3s 149ms/step - loss: 0.3826 - accuracy: 0.9701 - val_loss: 0.5843 - val_accuracy: 0.8553
# Epoch 69/100
# 20/20 [==============================] - 3s 145ms/step - loss: 0.3475 - accuracy: 0.9811 - val_loss: 0.5805 - val_accuracy: 0.8805
# Epoch 70/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3604 - accuracy: 0.9796 - val_loss: 0.6036 - val_accuracy: 0.8805
# Epoch 71/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3781 - accuracy: 0.9796 - val_loss: 0.5823 - val_accuracy: 0.8868
# Epoch 72/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3286 - accuracy: 0.9748 - val_loss: 0.5907 - val_accuracy: 0.8616
# Epoch 73/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3791 - accuracy: 0.9654 - val_loss: 0.5834 - val_accuracy: 0.8805
# Epoch 74/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.3592 - accuracy: 0.9796 - val_loss: 0.5791 - val_accuracy: 0.8805
# Epoch 75/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.3507 - accuracy: 0.9701 - val_loss: 0.5948 - val_accuracy: 0.8868
# Epoch 76/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3442 - accuracy: 0.9827 - val_loss: 0.5736 - val_accuracy: 0.8679
# Epoch 77/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3374 - accuracy: 0.9874 - val_loss: 0.5744 - val_accuracy: 0.8742
# Epoch 78/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3450 - accuracy: 0.9780 - val_loss: 0.5742 - val_accuracy: 0.8868
# Epoch 79/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.2830 - accuracy: 0.9780 - val_loss: 0.5664 - val_accuracy: 0.8868
# Epoch 80/100
# 20/20 [==============================] - 3s 146ms/step - loss: 0.3519 - accuracy: 0.9764 - val_loss: 0.5603 - val_accuracy: 0.8931
# Epoch 81/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3082 - accuracy: 0.9733 - val_loss: 0.5731 - val_accuracy: 0.8742
# Epoch 82/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3454 - accuracy: 0.9670 - val_loss: 0.5879 - val_accuracy: 0.8679
# Epoch 83/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3094 - accuracy: 0.9827 - val_loss: 0.5778 - val_accuracy: 0.8742
# Epoch 84/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3254 - accuracy: 0.9827 - val_loss: 0.5541 - val_accuracy: 0.8868
# Epoch 85/100
# 20/20 [==============================] - 3s 136ms/step - loss: 0.3260 - accuracy: 0.9874 - val_loss: 0.5497 - val_accuracy: 0.8805
# Epoch 86/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2839 - accuracy: 0.9890 - val_loss: 0.5463 - val_accuracy: 0.8931
# Epoch 87/100
# 20/20 [==============================] - 10s 522ms/step - loss: 0.3039 - accuracy: 0.9764 - val_loss: 0.5328 - val_accuracy: 0.9057
# Epoch 88/100
# 20/20 [==============================] - 6s 303ms/step - loss: 0.3368 - accuracy: 0.9733 - val_loss: 0.5341 - val_accuracy: 0.9119
# Epoch 89/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.3247 - accuracy: 0.9858 - val_loss: 0.5274 - val_accuracy: 0.8994
# Epoch 90/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2783 - accuracy: 0.9906 - val_loss: 0.5313 - val_accuracy: 0.9057
# Epoch 91/100
# 20/20 [==============================] - 3s 150ms/step - loss: 0.3219 - accuracy: 0.9811 - val_loss: 0.5222 - val_accuracy: 0.9119
# Epoch 92/100
# 20/20 [==============================] - 3s 143ms/step - loss: 0.3017 - accuracy: 0.9858 - val_loss: 0.5337 - val_accuracy: 0.8868
# Epoch 93/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.3145 - accuracy: 0.9827 - val_loss: 0.5403 - val_accuracy: 0.8994
# Epoch 94/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3189 - accuracy: 0.9796 - val_loss: 0.5265 - val_accuracy: 0.8931
# Epoch 95/100
# 20/20 [==============================] - 3s 139ms/step - loss: 0.3025 - accuracy: 0.9827 - val_loss: 0.5623 - val_accuracy: 0.8868
# Epoch 96/100
# 20/20 [==============================] - 3s 137ms/step - loss: 0.2841 - accuracy: 0.9874 - val_loss: 0.5442 - val_accuracy: 0.8742
# Epoch 97/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.2567 - accuracy: 0.9827 - val_loss: 0.5190 - val_accuracy: 0.9057
# Epoch 98/100
# 20/20 [==============================] - 3s 138ms/step - loss: 0.3024 - accuracy: 0.9874 - val_loss: 0.5128 - val_accuracy: 0.8805
# Epoch 99/100
# 20/20 [==============================] - 3s 135ms/step - loss: 0.3035 - accuracy: 0.9890 - val_loss: 0.5215 - val_accuracy: 0.8868
# Epoch 100/100
# 20/20 [==============================] - 3s 140ms/step - loss: 0.2700 - accuracy: 0.9858 - val_loss: 0.5249 - val_accuracy: 0.8868

# %%
#for split in range(len(results_val)):
print('Train accuracy')
print(np.amax(np.array(results_acc), axis=1))
print('Test accuracy')
print(np.amax(np.array(results_val), axis=1))
np.save('drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/'+dataset+'/'+dataset+'_train_log.npy', np.array(results_acc))
np.save('drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/'+dataset+'/'+dataset+'_test_log.npy', np.array(results_val))

# %% [markdown]
# # Selective Kernel Transfer

# %%
# some utilities to find the kernel entropies
#--------------------------------------------------------------------------------------------------
# get the distribution of a kernel
def get_distribution(output_list):
  #Get the histogram of the output in a hidden layer
  if np.amax(output_list)==0:
    x=np.histogram(output_list, np.arange(101)/100.0)
    return x[0]
  else:
    x=np.histogram(output_list/np.amax(output_list), np.arange(101)/100.0)
    return x[0]/float(np.sum(x[0]))
#--------------------------------------------------------------------------------------------------
# Find the entropy of a distribution
def distribution_entropy(distribution):
  entropy=0.0
  for dim in distribution:
    if dim!=0:
      entropy-=(dim*math.log2(dim))
  return entropy
#--------------------------------------------------------------------------------------------------
# Get the output of a convolutional layer
def get_output(layer_name, x_set, model):
  #Get the model for an output layer
  output_layer = Model(inputs=model.input, outputs=model.get_layer(layer_name).output)
  #return the output of the layer
  return output_layer.predict(np.array(x_set))

#--------------------------------------------------------------------------------------------------
# Find the entropy of each kernel
# The shape of the tensor is 4-dimensional, example: (680, 112, 112, 64)
# each element correspond to: (680)->number of instances, 
#                             (112,112)->shape of the output
#                             (64)-> number of kernels
# so, the information of the kernels is in the last position

def get_kernel_entropy(output_list):
  entropies=[]
  for i in range(output_list.shape[-1]):
    entropies.append(distribution_entropy(get_distribution(output_list[:,:,:,i])))
  return entropies
#--------------------------------------------------------------------------------------------------
# get the kernels to transfer
def obtain_k_to_transfer(x, model_path):
  k_to_transfer=[]
  model=keras.models.load_model(model_path)
  new_weigths=[]
  past=0
  for block in ['conv2d','Conv2d_1','Conv2d_2','Conv2d_3','Conv2d_4']:
    entropies=get_kernel_entropy(get_output(block,list(x),model))
    sorted_entropies_index=sorted(range(len(entropies)), key=lambda k: entropies[k])[:int(len(entropies)/2)]
    if past==0:
      new_weigths.append([model.get_layer(block).get_weights()[0][:,:,:,np.sort(sorted_entropies_index)],model.get_layer(block).get_weights()[1][np.sort(sorted_entropies_index)]])
    else:
      new_weigths.append([model.get_layer(block).get_weights()[0][:,:,np.sort(past)][:,:,:,np.sort(sorted_entropies_index)],
                         model.get_layer(block).get_weights()[1][np.sort(sorted_entropies_index)]])
    past=sorted_entropies_index
  return new_weigths

# %%
def AlexNetModel_50():
  # Create AlexNet architecture
  AlexNet=Sequential()

  #1st Convolutional Layer
  AlexNet.add(Conv2D(filters=48, input_shape=(224,224,3), kernel_size=(11,11), strides=(4,4), padding='same', name='Conv2d'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #2nd Convolutional Layer
  AlexNet.add(Conv2D(filters=128, kernel_size=(5, 5), strides=(1,1), padding='same', name='Conv2d_1'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #3rd Convolutional Layer
  AlexNet.add(Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_2'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))

  #4th Convolutional Layer
  AlexNet.add(Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_3'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))

  #5th Convolutional Layer
  AlexNet.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', name='Conv2d_4'))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  AlexNet.add(MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same'))

  #Passing it to a Fully Connected layer
  AlexNet.add(Flatten())
  # 1st Fully Connected Layer
  AlexNet.add(Dense(4096, input_shape=(32,32,3,)))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  # Add Dropout to prevent overfitting
  AlexNet.add(Dropout(0.4))

  #2nd Fully Connected Layer
  AlexNet.add(Dense(4096))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  #Add Dropout
  AlexNet.add(Dropout(0.4))

  #3rd Fully Connected Layer
  AlexNet.add(Dense(1000))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('relu'))
  #Add Dropout
  AlexNet.add(Dropout(0.4))

  #Output Layer
  AlexNet.add(Dense(len(classes)))
  AlexNet.add(BatchNormalization())
  AlexNet.add(Activation('softmax'))

  return AlexNet

# %%
def experiment():
  # To compare our work, the SOTA repeat 5-fold 2 times
  # create k-fold with k=5
  kfold = RepeatedKFold(n_splits=5, n_repeats=2)
  results_acc=[]
  results_val=[]
  cont_g=1

  for train, test in kfold.split(x):
    tensorflow.keras.backend.clear_session()
    print('-------------------------------------------------------------------------------------')
    print('Split:',cont_g)
    print('-------------------------------------------------------------------------------------')
    
    #get the new model
    #model=AlexNetModel()
    # callback to save the best models
    #checkpoint_filepath = 'drive/MyDrive/Multi-Source-Experiments/Selective_Transfer/'+dataset+'/checkpoint_'+str(cont)+'.h5'
    n_w=obtain_k_to_transfer(x, '/content/drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/webcam/checkpoint_6.h5')
    cont=0
    model=AlexNetModel_50()
    for block in ['Conv2d','Conv2d_1','Conv2d_2','Conv2d_3','Conv2d_4']:
      model.get_layer(block).set_weights(n_w[cont])
      cont+=1
    #model_checkpoint=tensorflow.keras.callbacks.ModelCheckpoint(
    #  filepath=checkpoint_filepath,
    #  save_weights_only=False,
    #  monitor='val_accuracy',
    #  mode='max',
    #  save_best_only=True)
    # compile, fit the model and save the model
    model.compile(loss = keras.losses.categorical_crossentropy, optimizer= tensorflow.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9), metrics=['accuracy'])
    #history=model.fit(x[train] , to_categorical(y[train]), validation_data=(x[test], to_categorical(y[test])), epochs = 100, callbacks=[model_checkpoint], batch_size=32)
    history=model.fit(x[train] , to_categorical(y[train]), validation_data=(x[test], to_categorical(y[test])), epochs = 100, batch_size=32)
    results_acc.append((history.history['accuracy']))
    results_val.append((history.history['val_accuracy']))
    #for split in range(len(results_val)):
  print('Train accuracy')
  print(np.amax(np.array(results_acc), axis=1))
  print('Test accuracy')
  print(np.amax(np.array(results_val), axis=1))
  np.save('drive/MyDrive/Multi-Source-Experiments/Selective_Transfer/'+dataset+'/'+dataset+'_train_log.npy', np.array(results_acc))
  np.save('drive/MyDrive/Multi-Source-Experiments/Selective_Transfer/'+dataset+'/'+dataset+'_test_log.npy', np.array(results_val))
  cont_g+=1
experiment()

# %%
#for split in range(len(results_val)):
print('Train accuracy')
print(np.amax(np.array(results_acc), axis=1))
print('Test accuracy')
print(np.amax(np.array(results_val), axis=1))
np.save('drive/MyDrive/Multi-Source-Experiments/Selective_Transfer/'+dataset+'/'+dataset+'_train_log.npy', np.array(results_acc))
np.save('drive/MyDrive/Multi-Source-Experiments/Selective_Transfer/'+dataset+'/'+dataset+'_test_log.npy', np.array(results_val))

# %% [markdown]
# # Multi Source Transfer Learning

# %%
from keras.utils.vis_utils import plot_model
classes=range(31)
def Multi_Source(nw_b1, nw_b2):
  #Multisource transfer version for multisource transfer
  #Alex_Net_M=Sequential()
  inputs=Input(shape=(224,224,3))

  #------------------------------------------------------------------------------------
  #Branch_1
  #------------------------------------------------------------------------------------
  #1st Convolutional Layer
  b1=Conv2D(filters=48, kernel_size=(11,11), strides=(4,4), padding='same', name='b1_conv2d')(inputs)
  b1=BatchNormalization()(b1)
  b1=Activation('relu')(b1)
  b1=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b1)

  #2nd Convolutional Layer
  b1=Conv2D(filters=128, kernel_size=(5, 5), strides=(1,1), padding='same', name='b1_Conv2d_1')(b1)
  b1=BatchNormalization()(b1)
  b1=Activation('relu')(b1)
  b1=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b1)

  #3rd Convolutional Layer
  b1=Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='b1_Conv2d_2')(b1)
  b1=BatchNormalization()(b1)
  b1=Activation('relu')(b1)

  #4th Convolutional Layer
  b1=Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='b1_Conv2d_3')(b1)
  b1=BatchNormalization()(b1)
  b1=Activation('relu')(b1)

  #5th Convolutional Layer
  b1=Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', name='b1_Conv2d_4')(b1)
  b1=BatchNormalization()(b1)
  b1=Activation('relu')(b1)
  b1=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b1)

  #------------------------------------------------------------------------------------
  #Branch_2
  #------------------------------------------------------------------------------------
  b2=Conv2D(filters=48, kernel_size=(11,11), strides=(4,4), padding='same', name='b2_conv2d')(inputs)
  b2=BatchNormalization()(b2)
  b2=Activation('relu')(b2)
  b2=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b2)

  #2nd Convolutional Layer
  b2=Conv2D(filters=128, kernel_size=(5, 5), strides=(1,1), padding='same', name='b2_Conv2d_1')(b2)
  b2=BatchNormalization()(b2)
  b2=Activation('relu')(b2)
  b2=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b2)

  #3rd Convolutional Layer
  b2=Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='b2_Conv2d_2')(b2)
  b2=BatchNormalization()(b2)
  b2=Activation('relu')(b2)

  #4th Convolutional Layer
  b2=Conv2D(filters=192, kernel_size=(3,3), strides=(1,1), padding='same', name='b2_Conv2d_3')(b2)
  b2=BatchNormalization()(b2)
  b2=Activation('relu')(b2)

  #5th Convolutional Layer
  b2=Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), padding='same', name='b2_Conv2d_4')(b2)
  b2=BatchNormalization()(b2)
  b2=Activation('relu')(b2)
  b2=MaxPooling2D(pool_size=(2,2), strides=(2,2), padding='same')(b2)
  join=concatenate([b1,b2])
  #Passing it to a Fully Connected layer
  join=Flatten()(join)
  # 1st Fully Connected Layer
  join=Dense(4096, input_shape=(32,32,3,))(join)
  join=BatchNormalization()(join)
  join=Activation('relu')(join)
  # Add Dropout to prevent overfitting
  join=Dropout(0.4)(join)

  #2nd Fully Connected Layer
  join=Dense(4096)(join)
  join=BatchNormalization()(join)
  join=Activation('relu')(join)
  #Add Dropout
  join=Dropout(0.4)(join)

  #3rd Fully Connected Layer
  join=Dense(1000)(join)
  join=BatchNormalization()(join)
  join=Activation('relu')(join)
  #Add Dropout
  join=Dropout(0.4)(join)

  #Output Layer
  join=Dense(len(classes))(join)
  join=BatchNormalization()(join)
  join=Activation('softmax')(join)


  Alex_Net_M= Model(inputs, join)
  cont=0
  for block in ['conv2d','Conv2d_1','Conv2d_2','Conv2d_3','Conv2d_4']:
    Alex_Net_M.get_layer('b1_'+block).set_weights(nw_b1[cont])
    Alex_Net_M.get_layer('b2_'+block).set_weights(nw_b2[cont])
    cont+=1


branch_1=obtain_k_to_transfer(x, '/content/drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/webcam/checkpoint_6.h5')
branch_2=obtain_k_to_transfer(x, '/content/drive/MyDrive/Multi-Source-Experiments/Train_From_Scratch/webcam/checkpoint_6.h5')
Multi_Source(branch_1, branch_2)
